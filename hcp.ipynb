# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('data\HCP-Dimension.csv')

# %%
df.head()
# Out:
#     DoctorID  Doctor first name  Doctor last name  Doctor middle name  \
# 0  1270575.0              Hzzzz              Heee             Vdddddd
# 1  1423757.0              Rkkkk           Syyyyyy               Jjjjj
# 2  2030384.0               Aqqq            Qbbbbb                Jyyy
# 3  1573852.0             Ikkkkk             Nuuuu               Ewwww
# 4  1480166.0             Maaaaa          Uuuuuuuu                 Cpp
#
#   Primary  specialty code  Primary  specialty description  \
# 0                     HEM  HEMATOLOGY (INTERNAL MEDICINE)
# 1                       D                     DERMATOLOGY
# 2                      ON                MEDICAL ONCOLOGY
# 3                      IM               INTERNAL MEDICINE
# 4                      FM                 FAMILY MEDICINE
#
#   Secondary specialty code Secondary specilaty description  Doctor state  \
# 0                       ON                MEDICAL ONCOLOGY       ARIZONA
# ...

# %%
print(df.columns)
# Out:
# Index([' DoctorID', ' Doctor first name', ' Doctor last name',
#        ' Doctor middle name', 'Primary  specialty code',
#        'Primary  specialty description', 'Secondary specialty code',
#        'Secondary specilaty description', ' Doctor state',
#        ' Doctor state code', ' Doctor zip'],
#       dtype='object')

# %%
# print(df[' DoctorID'].nunique())
# print(df[' DoctorID'].unique())
# df.drop_duplicates(subset=[' DoctorID'], keep='first')

# %%
print(df[' DoctorID'].nunique())
# Out:
# 9994

# %%
# df.describe

# %%
df.drop_duplicates(subset=[' DoctorID'])
# Out:
#         DoctorID  Doctor first name  Doctor last name  Doctor middle name  \
# 0      1270575.0              Hzzzz              Heee             Vdddddd
# 1      1423757.0              Rkkkk           Syyyyyy               Jjjjj
# 2      2030384.0               Aqqq            Qbbbbb                Jyyy
# 3      1573852.0             Ikkkkk             Nuuuu               Ewwww
# 4      1480166.0             Maaaaa          Uuuuuuuu                 Cpp
# ...          ...                ...               ...                 ...
# 9996   3175192.0               Rvvv             Eiiii
# 9997   1683030.0            Taaaaaa         Jaaaaaaaa              Sccccc
# 9998   3248009.0           Hmmmmmmm         Ixxxxxxxx                   F
# 9999   4073041.0            Ujjjjjj              Duuu               Ztttt
# 10000        NaN                NaN               NaN
#
#       Primary  specialty code  Primary  specialty description  \
# ...

# %%
# df.describe()
# Check for duplicate rows
duplicates = df.duplicated()

# Print the duplicate rows
print(df[duplicates])
# Out:
# Empty DataFrame
# Columns: [ DoctorID,  Doctor first name,  Doctor last name,  Doctor middle name, Primary  specialty code, Primary  specialty description, Secondary specialty code, Secondary specilaty description,  Doctor state,  Doctor state code,  Doctor zip]
# Index: []

# %%
df.drop([ 'Primary  specialty code'],axis=1,inplace=True)

# %%
df.head()
# Out:
#     DoctorID Primary  specialty code  Primary  specialty description  \
# 0  1270575.0                     HEM  HEMATOLOGY (INTERNAL MEDICINE)
# 1  1423757.0                       D                     DERMATOLOGY
# 2  2030384.0                      ON                MEDICAL ONCOLOGY
# 3  1573852.0                      IM               INTERNAL MEDICINE
# 4  1480166.0                      FM                 FAMILY MEDICINE
#
#   Secondary specialty code Secondary specilaty description  Doctor state  \
# 0                       ON                MEDICAL ONCOLOGY       ARIZONA
# 1                       FM                 FAMILY MEDICINE  PENNSYLVANIA
# 2                       IM               INTERNAL MEDICINE         TEXAS
# 3                      NaN                             NaN       FLORIDA
# 4                      NaN                             NaN    WASHINGTON
#
#    Doctor state code   Doctor zip
# 0                 AZ      85006.0
# 1                 PA      19609.0
# ...

# %%
df.dropna(subset=["Primary  specialty code"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19872\146984070.py in ?()
# ----> 1 df.dropna(subset=["Primary  specialty code"])
#
# c:\GitHub\trinity\insurance-analysis\trinity\lib\site-packages\pandas\core\frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6650             ax = self._get_axis(agg_axis)
#    6651             indices = ax.get_indexer_for(subset)
#    6652             check = indices == -1
#    6653             if check.any():
# -> 6654                 raise KeyError(np.array(subset)[check].tolist())
#    6655             agg_obj = self.take(indices, axis=agg_axis)
#    6656
#    6657         if thresh is not lib.no_default:
#
# KeyError: ['Primary  specialty code']

# %%
df.columns
# Out:
# Index([' DoctorID', 'Primary  specialty description',
#        'Secondary specialty code', 'Secondary specilaty description',
#        ' Doctor state', ' Doctor state code', ' Doctor zip'],
#       dtype='object')
